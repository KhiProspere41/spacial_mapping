# %% [markdown]
# # 📘 01 - For Loops
#
# Learn how to use `for` loops to iterate over sequences.

# %% [markdown]
# ## ✅ Learning Goals
# - Use `for` with lists, strings, and `range()`
# - Understand loop variables and block structure

# %%
# 🔁 Loop over a list
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(fruit)

# %%
# 🔁 Loop over characters in a string
word = 'hello'
for char in word:
    print(char)

# %%
# 🔁 Using range()
for i in range(5):
    print(i)

# %%
# ➕ Loop with math
for i in range(1, 6):
    print(f'{i} squared is', i ** 2)

# %% [markdown]
# ### ✏️ Your Turn
# Loop over a list of 3 favorite movies and print them in all caps.

# %%
#List of favorite movies
movies = ["Grown-Ups", "Spider-Man: Into the Spider-Verse", "Se7en"]

# 🔁 Loop and print in all caps
for movie in movies:
    print(movie.upper())
# Out:
# GROWN-UPS
# SPIDER-MAN: INTO THE SPIDER-VERSE
# SE7EN
