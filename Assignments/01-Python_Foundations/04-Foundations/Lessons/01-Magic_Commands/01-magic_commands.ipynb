# %% [markdown]
# # 🧙 Magic Commands Demo Notebook
#
# This notebook introduces some of the most useful **IPython magic commands** in Jupyter.
# Run each cell and see what happens!

# %% [markdown]
# ## 1. Timing and Performance

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 23 ms, sys: 0 ns, total: 23 ms
# Wall time: 30 ms
# 499999500000

# %%
# %timeit sum(range(1_000_000))
# Out:
# 18.1 ms ± 1.56 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
# Out:
# CPU times: user 106 ms, sys: 1.97 ms, total: 108 ms
# Wall time: 114 ms

# %% [markdown]
# ## 2. Working with Files

# %%
# %pwd
# Out:
# '/workspaces/spacial_mapping/Assignments/01-Python_Foundations/04-Foundations/Lessons/01-Magic_Commands'

# %%
# %ls
# Out:
# 01-magic_commands.ipynb  README.md  _autogen.md  _header.md  meta.yaml

# %%
# %cd ..
# %pwd
# Out:
# /workspaces/spacial_mapping/Assignments/01-Python_Foundations/04-Foundations/Lessons
# '/workspaces/spacial_mapping/Assignments/01-Python_Foundations/04-Foundations/Lessons'

# %% [markdown]
# ## 3. Variables in Memory

# %%
a = 42
b = [1, 2, 3]
c = {"name": "Graylian"}

# %who
# Out:
# a	 b	 c	 i	 total

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     42
# b          list    n=3
# c          dict    n=1
# i          int     999999
# total      int     499999500000

# %%
# %reset

# %% [markdown]
# ## 4. Debugging and Introspection

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > /tmp/ipykernel_38606/1455669704.py(1)<module>()
# ----> 1 1 / 0

# %% [markdown]
# ## 5. Writing and Running Files

# %%
# %%writefile hello.py
print("Hello from a file!")

# %%
# %run hello.py

# %% [markdown]
# ## 6. Output and Formatting

# %%
# %%capture cap
print("This will not display right away")

cap.show()

# %%
# %%html
# <h1 style="color: maroon">Magics are Magical ✨</h1>

# %%
# %%markdown
# # This is a Markdown cell inside code!
# **Bold text** and *italic* still work.

# %% [markdown]
# ## 7. Discover More

# %%
# %lsmagic

# %%
# %timeit?

# %% [markdown]
# ✅ **Try It Yourself**:
# - Use `%timeit` to compare a list comprehension `[x**2 for x in range(1000)]` vs a generator `(x**2 for x in range(1000))`.
# - Use `%whos` after defining some variables to see their types.
# - Use `%%html` to make your own banner.

# %%
# Comparison
# %timeit [x**2 for x in range(1000)]
# %timeit (x**2 for x in range(1000))

# Check variables with %whos
x = 10
y = [1, 2, 3, 4]
name = "Python"

# %whos


# Create a banner
# %%html
<h1 style="color: blue; text-align: center;">
🚀 Welcome to My Notebook 🚀
</h1>
<p style="text-align: center;">
Learning Python is actually fun.
</p>
# Out:
#   Cell In[1], line 16
#     🚀 Welcome to My Notebook 🚀
#     ^
# SyntaxError: invalid character '🚀' (U+1F680)
