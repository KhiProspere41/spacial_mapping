# %% [markdown]
# # 📘 01 - Scalar Types
#
# Review and practice working with Python's basic scalar data types.

# %% [markdown]
# ## ✅ Learning Goals
# - Recognize scalar types (`int`, `float`, `str`, `bool`)
# - Use the `type()` function to identify types
# - Use variables and assignment

# %%
# 🔧 Define some variables
num = 42
pi = 3.14159
name = 'Python'
is_cool = True

# %%
# 🔍 Check their types
print(type(num))
print(type(pi))
print(type(name))
print(type(is_cool))

# %% [markdown]
# ### ✏️ Your Turn
# Create your own variables of each type and print them.

# %%
jersey_number = 23          
shooting_percentage = 0.458 
sport = 'Basketball'       
is_graduating_soon = True   


print(type(jersey_number))
print(type(shooting_percentage))
print(type(sport))
print(type(is_graduating_soon))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## ⚖️ Comparison Practice
# Use comparison operators to check values.

# %%
x = 10
y = 5
print(x > y)
print(x == y)
print(x != y)
# Out:
# True
# False
# True

# %% [markdown]
# ## 🧠 Quick Check
# What will the following print?
# ```python
# print(3.0 == 3)
# ```

# %%
print(3.0 == 3)
# Out:
# True
